# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
customer_churn = pd.read_csv("Customer_Churn.csv")

# %%
customer_churn.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
customer_churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
customer_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_churn.drop('customerID', axis = 1, inplace = True)

# %%
customer_churn
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
# removing irrelevant columns
customer_churn.drop(['Partner','Dependents','TechSupport','Contract'], axis = 1, inplace = True)
# Out:
#       gender  SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0     Female              0       1           No  No phone service
# 1       Male              0      34          Yes                No
# 2       Male              0       2          Yes                No
# 3       Male              0      45           No  No phone service
# 4     Female              0       2          Yes                No
# ...      ...            ...     ...          ...               ...
# 7038    Male              0      24          Yes               Yes
# 7039  Female              0      72          Yes               Yes
# 7040  Female              0      11           No  No phone service
# 7041    Male              1       4          Yes               Yes
# 7042    Male              0      66          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection StreamingTV  \
# 0                DSL             No          Yes               No          No
# ...

# %%
customer_churn
# Out:
#       gender  SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0     Female              0       1           No  No phone service
# 1       Male              0      34          Yes                No
# 2       Male              0       2          Yes                No
# 3       Male              0      45           No  No phone service
# 4     Female              0       2          Yes                No
# ...      ...            ...     ...          ...               ...
# 7038    Male              0      24          Yes               Yes
# 7039  Female              0      72          Yes               Yes
# 7040  Female              0      11           No  No phone service
# 7041    Male              1       4          Yes               Yes
# 7042    Male              0      66          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection StreamingTV  \
# 0                DSL             No          Yes               No          No
# ...

# %%
customer_churn.to_csv("task2_1.csv")

# %%
task2_1 = pd.read_csv("task2_1.csv")

# %%
task2_1
# Out:
#       Unnamed: 0  gender  SeniorCitizen  tenure PhoneService  \
# 0              0  Female              0       1           No
# 1              1    Male              0      34          Yes
# 2              2    Male              0       2          Yes
# 3              3    Male              0      45           No
# 4              4  Female              0       2          Yes
# ...          ...     ...            ...     ...          ...
# 7038        7038    Male              0      24          Yes
# 7039        7039  Female              0      72          Yes
# 7040        7040  Female              0      11           No
# 7041        7041    Male              1       4          Yes
# 7042        7042    Male              0      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# ...

# %%
task2_1
# Out:
#       Unnamed: 0  gender  SeniorCitizen  tenure PhoneService  \
# 0              0  Female              0       1           No
# 1              1    Male              0      34          Yes
# 2              2    Male              0       2          Yes
# 3              3    Male              0      45           No
# 4              4  Female              0       2          Yes
# ...          ...     ...            ...     ...          ...
# 7038        7038    Male              0      24          Yes
# 7039        7039  Female              0      72          Yes
# 7040        7040  Female              0      11           No
# 7041        7041    Male              1       4          Yes
# 7042        7042    Male              0      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# ...

# %%
# dropping null rows
task2_1.dropna()
# Out:
#       Unnamed: 0  gender  SeniorCitizen  tenure PhoneService  \
# 0              0  Female              0       1           No
# 1              1    Male              0      34          Yes
# 2              2    Male              0       2          Yes
# 3              3    Male              0      45           No
# 4              4  Female              0       2          Yes
# ...          ...     ...            ...     ...          ...
# 7038        7038    Male              0      24          Yes
# 7039        7039  Female              0      72          Yes
# 7040        7040  Female              0      11           No
# 7041        7041    Male              1       4          Yes
# 7042        7042    Male              0      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# ...

# %%
task2_1
# Out:
#       Unnamed: 0  gender  SeniorCitizen  tenure PhoneService  \
# 0              0  Female              0       1           No
# 1              1    Male              0      34          Yes
# 2              2    Male              0       2          Yes
# 3              3    Male              0      45           No
# 4              4  Female              0       2          Yes
# ...          ...     ...            ...     ...          ...
# 7038        7038    Male              0      24          Yes
# 7039        7039  Female              0      72          Yes
# 7040        7040  Female              0      11           No
# 7041        7041    Male              1       4          Yes
# 7042        7042    Male              0      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# ...

# %%
task2_2 = pd.read_csv("task2_2.csv")

# %%
task2_2
# Out:
#       gender  SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0     Female              0       1           No  No phone service
# 1       Male              0      34          Yes                No
# 2       Male              0       2          Yes                No
# 3       Male              0      45           No  No phone service
# 4     Female              0       2          Yes                No
# ...      ...            ...     ...          ...               ...
# 7038    Male              0      24          Yes               Yes
# 7039  Female              0      72          Yes               Yes
# 7040  Female              0      11           No  No phone service
# 7041    Male              1       4          Yes               Yes
# 7042    Male              0      66          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection StreamingTV  \
# 0                DSL             No          Yes               No          No
# ...

# %%
# binarizing churn column yes to 1 and no to 0
task2_2.Churn.replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
task2_2
# Out:
#       gender  SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0     Female              0       1           No  No phone service
# 1       Male              0      34          Yes                No
# 2       Male              0       2          Yes                No
# 3       Male              0      45           No  No phone service
# 4     Female              0       2          Yes                No
# ...      ...            ...     ...          ...               ...
# 7038    Male              0      24          Yes               Yes
# 7039  Female              0      72          Yes               Yes
# 7040  Female              0      11           No  No phone service
# 7041    Male              1       4          Yes               Yes
# 7042    Male              0      66          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection StreamingTV  \
# 0                DSL             No          Yes               No          No
# ...

# %%
#task2_2.PhoneService.replace(('Yes', 'No'), (1, 0), inplace=True)
task2_2.OnlineSecurity.replace(('No internet service'), (0), inplace=True)
task2_2.OnlineBackup.replace(('No internet service'), (0), inplace=True)
task2_2.DeviceProtection.replace(('No internet service'), (0), inplace=True)
task2_2.StreamingTV.replace(('No internet service'), (0), inplace=True)
task2_2.StreamingMovies.replace(('No internet service'), (0), inplace=True)
#task2_2.PaperlessBilling.replace(('No internet service'), (1, 0), inplace=True)

# %%
task2_2
# Out:
#       gender  SeniorCitizen  tenure  PhoneService  MultipleLines  \
# 0     Female              0       1             0              0
# 1       Male              0      34             1              0
# 2       Male              0       2             1              0
# 3       Male              0      45             0              0
# 4     Female              0       2             1              0
# ...      ...            ...     ...           ...            ...
# 7038    Male              0      24             1              1
# 7039  Female              0      72             1              1
# 7040  Female              0      11             0              0
# 7041    Male              1       4             1              1
# 7042    Male              0      66             1              0
#
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0                DSL               0             1                 0
# ...

# %%
task2_2.MultipleLines.replace(('Yes', 'No', 'No phone service'), (1, 0, 0), inplace=True)

# %%
task2_2
# Out:
#       gender  SeniorCitizen  tenure  PhoneService  MultipleLines  \
# 0     Female              0       1             0              0
# 1       Male              0      34             1              0
# 2       Male              0       2             1              0
# 3       Male              0      45             0              0
# 4     Female              0       2             1              0
# ...      ...            ...     ...           ...            ...
# 7038    Male              0      24             1              1
# 7039  Female              0      72             1              1
# 7040  Female              0      11             0              0
# 7041    Male              1       4             1              1
# 7042    Male              0      66             1              0
#
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0                DSL               0             1                 0
# ...

# %%
task2_2.to_csv("task2_3.csv")
